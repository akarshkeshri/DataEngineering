# %%
import json
import requests
import os
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())

# %%
print(api_key)
# Out:
# 5JX7zjQ85Z5Vm7VkgznmsNae67YeOn8b

# %%
api_key = os.getenv('NewYork_API_KEY')
secret_key = os.getenv('NewYork_SECRET_KEY')

# %%
import requests

# Define the API endpoint
url = 'https://openlibrary.org/books/OL7353617M.json'

# Make the GET request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    print(data)
else:
    print(f"Error: {response.status_code}")
# Out:
# {'identifiers': {'goodreads': ['1507552'], 'librarything': ['6446']}, 'title': 'Fantastic Mr. Fox', 'authors': [{'key': '/authors/OL34184A'}], 'publish_date': 'October 1, 1988', 'publishers': ['Puffin'], 'covers': [8739161], 'contributions': ['Tony Ross (Illustrator)'], 'languages': [{'key': '/languages/eng'}], 'source_records': ['promise:bwb_daily_pallets_2021-05-13:KP-140-654', 'ia:fantasticmrfox00dahl_834', 'marc:marc_openlibraries_sanfranciscopubliclibrary/sfpl_chq_2018_12_24_run02.mrc:85081404:4525', 'amazon:0140328726', 'bwb:9780140328721', 'promise:bwb_daily_pallets_2021-04-19:KP-128-107', 'promise:bwb_daily_pallets_2020-04-30:O6-BTK-941'], 'local_id': ['urn:bwbsku:KP-140-654', 'urn:sfpl:31223064402481', 'urn:sfpl:31223117624784', 'urn:sfpl:31223113969183', 'urn:sfpl:31223117624800', 'urn:sfpl:31223113969225', 'urn:sfpl:31223106484539', 'urn:sfpl:31223117624792', 'urn:sfpl:31223117624818', 'urn:sfpl:31223117624768', 'urn:sfpl:31223117624743', 'urn:sfpl:31223113969209', 'urn:sf
# ...

# %%
headers={'Content-Type':'Application/json','x-api-key':api_key,'Authorization':secret_key}
url ='https://api.nytimes.com/svc/books/v3/lists.json'
params =  'hardcover-fiction'
api_name = 'NewYorkBook_api'       
import requests

def execute():
  requestUrl = f"https://api.nytimes.com/svc/books/v3/lists.json?list=hardcover-fiction&api-key={api_key}"
  requestHeaders = {
    "Accept": "application/json"
  }
  
  
  try:
    response = requests.get(requestUrl, headers=requestHeaders)
  except Exception as e:
        print(e)

  print(response.text)

# %%
import json

data = {
    "status": "OK",
    "copyright": "Copyright (c) 2025 The New York Times Company.  All Rights Reserved.",
    "num_results": 15,
    "last_modified": "2025-05-07T22:24:55-04:00",
    "results": [
        {
            "list_name": "Hardcover Fiction",
            "display_name": "Hardcover Fiction",
            "bestsellers_date": "2025-05-03",
            "published_date": "2025-05-18",
            "rank": 1,
            "rank_last_week": 1,
            "weeks_on_list": 2,
            "asterisk": 0,
            "dagger": 0,
            "amazon_product_url": "https://www.amazon.com/dp/059344129X?tag=thenewyorktim-20",
            "isbns": [
                {
                    "isbn10": "059344129X",
                    "isbn13": "9780593441299"
                },
                {
                    "isbn10": "0593441249",
                    "isbn13": "9780593441244"
                }
            ],
            "book_details": [
                {
                    "title": "GREAT BIG BEAUTIFUL LIFE",
                    "description": "A writer looking for her big break competes against a Pulitzer winner to tell the story of an octogenarian with a storied past.",
                    "contributor": "by Emily Henry",
                    "author": "Emily Henry",
                    "contributor_note": "",
                    "price": "0.00",
                    "age_group": "",
                    "publisher": "Berkley",
                    "primary_isbn13": "9780593441299",
                    "primary_isbn10": "059344129X"
                }
            ],
            "reviews": [
                {
                    "book_review_link": "",
                    "first_chapter_link": "",
                    "sunday_review_link": "",
                    "article_chapter_link": ""
                }
            ]
        },
        {
            "list_name": "Hardcover Fiction",
            "display_name": "Hardcover Fiction",
            "bestsellers_date": "2025-05-03",
            "published_date": "2025-05-18",
            "rank": 2,
            "rank_last_week": 0,
            "weeks_on_list": 1,
            "asterisk": 0,
            "dagger": 0,
            "amazon_product_url": "https://www.amazon.com/dp/0316569771?tag=thenewyorktim-20",
            "isbns": [
                {
                    "isbn10": "0316569771",
                    "isbn13": "9780316569774"
                },
                {
                    "isbn10": "031656978X",
                    "isbn13": "9780316569781"
                }
            ],
            "book_details": [
                {
                    "title": "25 ALIVE",
                    "description": "The 25th book in the Women\u2019s Murder Club series. Lindsay Boxer\u2019s former partner is the victim at a crime scene.",
                    "contributor": "by James Patterson and Maxine Paetro",
                    "author": "James Patterson and Maxine Paetro",
                    "contributor_note": "",
                    "price": "0.00",
                    "age_group": "",
                    "publisher": "Little, Brown",
                    "primary_isbn13": "9780316569774",
                    "primary_isbn10": "0316569771"
                }
            ],
            "reviews": [
                {
                    "book_review_link": "",
                    "first_chapter_link": "",
                    "sunday_review_link": "",
                    "article_chapter_link": ""
                }
            ]
        },
        {
            "list_name": "Hardcover Fiction",
            "display_name": "Hardcover Fiction",
            "bestsellers_date": "2025-05-03",
            "published_date": "2025-05-18",
            "rank": 3,
            "rank_last_week": 0,
            "weeks_on_list": 1,
            "asterisk": 0,
            "dagger": 0,
            "amazon_product_url": "https://www.amazon.com/dp/1250334233?tag=thenewyorktim-20",
            "isbns": [
                {
                    "isbn10": "1250334233",
                    "isbn13": "9781250334237"
                }
            ],
            "book_details": [
                {
                    "title": "ENIGMA",
                    "description": "Salem Salazar, a student at Mortimer University, where girls go missing, has a relationship with a teaching assistant who is her opposite.",
                    "contributor": "by RuNyx",
                    "author": "RuNyx",
                    "contributor_note": "",
                    "price": "0.00",
                    "age_group": "",
                    "publisher": "Bramble",
                    "primary_isbn13": "9781250334237",
                    "primary_isbn10": "1250334233"
                }
            ],
            "reviews": [
                {
                    "book_review_link": "",
                    "first_chapter_link": "",
                    "sunday_review_link": "",
                    "article_chapter_link": ""
                }
            ]
        },
        {
            "list_name": "Hardcover Fiction",
            "display_name": "Hardcover Fiction",
            "bestsellers_date": "2025-05-03",
            "published_date": "2025-05-18",
            "rank": 4,
            "rank_last_week": 0,
            "weeks_on_list": 1,
            "asterisk": 0,
            "dagger": 0,
            "amazon_product_url": "https://www.amazon.com/dp/0593498704?tag=thenewyorktim-20",
            "isbns": [
                {
                    "isbn10": "0593498704",
                    "isbn13": "9780593498705"
                },
                {
                    "isbn10": "0593498712",
                    "isbn13": "9780593498712"
                }
            ],
            "book_details": [
                {
                    "title": "A MIND OF HER OWN",
                    "description": "Alexandra Bouvier, who experiences losses due to war and the Spanish flu, connects with a reporter covering gang wars caused by Prohibition.",
                    "contributor": "by Danielle Steel",
                    "author": "Danielle Steel",
                    "contributor_note": "",
                    "price": "0.00",
                    "age_group": "",
                    "publisher": "Delacorte",
                    "primary_isbn13": "9780593498705",
                    "primary_isbn10": "0593498704"
                }
            ],
            "reviews": [
                {
                    "book_review_link": "",
                    "first_chapter_link": "",
                    "sunday_review_link": "",
                    "article_chapter_link": ""
                }
            ]
        },
        {
            "list_name": "Hardcover Fiction",
            "display_name": "Hardcover Fiction",
            "bestsellers_date": "2025-05-03",
            "published_date": "2025-05-18",
            "rank": 5,
            "rank_last_week": 2,
            "weeks_on_list": 3,
            "asterisk": 0,
            "dagger": 0,
            "amazon_product_url": "https://www.amazon.com/dp/B0DGY5F5JX?tag=thenewyorktim-20",
            "isbns": [],
            "book_details": [
                {
                    "title": "THE PERFECT DIVORCE",
                    "description": "Around the time of the disappearance of a woman who had a one-night stand with the attorney Sarah Morgan\u2019s new husband, police reopen the investigation into the murder of her first husband\u2019s mistress.",
                    "contributor": "by Jeneva Rose",
                    "author": "Jeneva Rose",
                    "contributor_note": "",
                    "price": "0.00",
                    "age_group": "",
                    "publisher": "Blackstone",
                    "primary_isbn13": "9798874620936",
                    "primary_isbn10": "None"
                }
            ],
            "reviews": [
                {
                    "book_review_link": "",
                    "first_chapter_link": "",
                    "sunday_review_link": "",
                    "article_chapter_link": ""
                }
            ]
        },
        {
            "list_name": "Hardcover Fiction",
            "display_name": "Hardcover Fiction",
            "bestsellers_date": "2025-05-03",
            "published_date": "2025-05-18",
            "rank": 6,
            "rank_last_week": 5,
            "weeks_on_list": 15,
            "asterisk": 0,
            "dagger": 0,
            "amazon_product_url": "https://www.amazon.com/dp/1649374186?tag=thenewyorktim-20",
            "isbns": [
                {
                    "isbn10": "1649374186",
                    "isbn13": "9781649374189"
                },
                {
                    "isbn10": "1649377150",
                    "isbn13": "9781649377159"
                },
                {
                    "isbn10": "1705085113",
                    "isbn13": "9781705085110"
                },
                {
                    "isbn10": "1420521861",
                    "isbn13": "9781420521863"
                },
                {
                    "isbn10": "1705085091",
                    "isbn13": "9781705085097"
                }
            ],
            "book_details": [
                {
                    "title": "ONYX STORM",
                    "description": "The third book in the Empyrean series. As enemies gain traction, Violet Sorrengail goes beyond the Aretian wards in search of allies.",
                    "contributor": "by Rebecca Yarros",
                    "author": "Rebecca Yarros",
                    "contributor_note": "",
                    "price": "0.00",
                    "age_group": "",
                    "publisher": "Red Tower",
                    "primary_isbn13": "9781649374189",
                    "primary_isbn10": "1649374186"
                }
            ],
            "reviews": [
                {
                    "book_review_link": "",
                    "first_chapter_link": "",
                    "sunday_review_link": "",
                    "article_chapter_link": ""
                }
            ]
        },
        {
            "list_name": "Hardcover Fiction",
            "display_name": "Hardcover Fiction",
            "bestsellers_date": "2025-05-03",
            "published_date": "2025-05-18",
            "rank": 7,
            "rank_last_week": 3,
            "weeks_on_list": 3,
            "asterisk": 0,
            "dagger": 0,
            "amazon_product_url": "https://www.amazon.com/dp/1538742055?tag=thenewyorktim-20",
            "isbns": [
                {
                    "isbn10": "1538742055",
                    "isbn13": "9781538742051"
                },
                {
                    "isbn10": "153874208X",
                    "isbn13": "9781538742082"
                }
            ],
            "book_details": [
                {
                    "title": "STRANGERS IN TIME",
                    "description": "In London in 1944, two teenagers dealing with the dangers of World War II form an alliance with a bookshop owner.",
                    "contributor": "by David Baldacci",
                    "author": "David Baldacci",
                    "contributor_note": "",
                    "price": "0.00",
                    "age_group": "",
                    "publisher": "Grand Central",
                    "primary_isbn13": "9781538742051",
                    "primary_isbn10": "1538742055"
                }
            ],
            "reviews": [
                {
                    "book_review_link": "",
                    "first_chapter_link": "",
                    "sunday_review_link": "",
                    "article_chapter_link": ""
                }
            ]
        },
        {
            "list_name": "Hardcover Fiction",
            "display_name": "Hardcover Fiction",
            "bestsellers_date": "2025-05-03",
            "published_date": "2025-05-18",
            "rank": 8,
            "rank_last_week": 0,
            "weeks_on_list": 1,
            "asterisk": 0,
            "dagger": 0,
            "amazon_product_url": "https://www.amazon.com/dp/0778308006?tag=thenewyorktim-20",
            "isbns": [
                {
                    "isbn10": "0778308006",
                    "isbn13": "9780778308003"
                }
            ],
            "book_details": [
                {
                    "title": "THE AMALFI CURSE",
                    "description": "When a nautical archaeologist investigates shipwrecks and seeks her late father\u2019s sunken treasure, she learns of a centuries-old tale involving magic.",
                    "contributor": "by Sarah Penner",
                    "author": "Sarah Penner",
                    "contributor_note": "",
                    "price": "0.00",
                    "age_group": "",
                    "publisher": "Park Row",
                    "primary_isbn13": "9780778387886",
                    "primary_isbn10": "None"
                }
            ],
            "reviews": [
                {
                    "book_review_link": "",
                    "first_chapter_link": "",
                    "sunday_review_link": "",
                    "article_chapter_link": ""
                }
            ]
        },
        {
            "list_name": "Hardcover Fiction",
            "display_name": "Hardcover Fiction",
            "bestsellers_date": "2025-05-03",
            "published_date": "2025-05-18",
            "rank": 9,
            "rank_last_week": 4,
            "weeks_on_list": 5,
            "asterisk": 0,
            "dagger": 0,
            "amazon_product_url": "https://www.amazon.com/dp/1538759195?tag=thenewyorktim-20",
            "isbns": [
                {
                    "isbn10": "1538759195",
                    "isbn13": "9781538759196"
                },
                {
                    "isbn10": "0349442835",
                    "isbn13": "9780349442839"
                },
                {
                    "isbn10": "1668644991",
                    "isbn13": "9781668644997"
                }
            ],
            "book_details": [
                {
                    "title": "SAY YOU'LL REMEMBER ME",
                    "description": "Despite having a great date, Samantha asks a veterinarian to forget about her because her family is in crisis.",
                    "contributor": "by Abby Jimenez",
                    "author": "Ab Jimenez",
                    "contributor_note": "",
                    "price": "0.00",
                    "age_group": "",
                    "publisher": "Forever",
                    "primary_isbn13": "9781538759196",
                    "primary_isbn10": "1538759195"
                }
            ],
            "reviews": [
                {
                    "book_review_link": "",
                    "first_chapter_link": "",
                    "sunday_review_link": "",
                    "article_chapter_link": ""
                }
            ]
        },
        {
            "list_name": "Hardcover Fiction",
            "display_name": "Hardcover Fiction",
            "bestsellers_date": "2025-05-03",
            "published_date": "2025-05-18",
            "rank": 10,
            "rank_last_week": 7,
            "weeks_on_list": 9,
            "asterisk": 0,
            "dagger": 0,
            "amazon_product_url": "https://www.amazon.com/dp/166807818X?tag=thenewyorktim-20",
            "isbns": [
                {
                    "isbn10": "166807818X",
                    "isbn13": "9781668078181"
                },
                {
                    "isbn10": "1668078201",
                    "isbn13": "9781668078204"
                },
                {
                    "isbn10": "1668144565",
                    "isbn13": "9781668144565"
                },
                {
                    "isbn10": "1420520725",
                    "isbn13": "9781420520729"
                }
            ],
            "book_details": [
                {
                    "title": "BROKEN COUNTRY",
                    "description": "Beth must confront her past when the man she once loved as a teenager returns to the village with his son.",
                    "contributor": "by Clare Leslie Hall",
                    "author": "Clare Leslie Hall",
                    "contributor_note": "",
                    "price": "0.00",
                    "age_group": "",
                    "publisher": "Simon & Schuster",
                    "primary_isbn13": "9781668078181",
                    "primary_isbn10": "166807818X"
                }
            ],
            "reviews": [
                {
                    "book_review_link": "",
                    "first_chapter_link": "",
                    "sunday_review_link": "",
                    "article_chapter_link": ""
                }
            ]
        },
        {
            "list_name": "Hardcover Fiction",
            "display_name": "Hardcover Fiction",
            "bestsellers_date": "2025-05-03",
            "published_date": "2025-05-18",
            "rank": 11,
            "rank_last_week": 6,
            "weeks_on_list": 78,
            "asterisk": 0,
            "dagger": 0,
            "amazon_product_url": "https://www.amazon.com/dp/1649374178?tag=thenewyorktim-20",
            "isbns": [
                {
                    "isbn10": "1649374178",
                    "isbn13": "9781649374172"
                },
                {
                    "isbn10": "1705085083",
                    "isbn13": "9781705085080"
                },
                {
                    "isbn10": "034943705X",
                    "isbn13": "9780349437057"
                }
            ],
            "book_details": [
                {
                    "title": "IRON FLAME",
                    "description": "The second book in the Empyrean series. Violet Sorrengail\u2019s next round of training under the new vice commandant might require her to betray the man she loves.",
                    "contributor": "by Rebecca Yarros",
                    "author": "Rebecca Yarros",
                    "contributor_note": "",
                    "price": "0.00",
                    "age_group": "",
                    "publisher": "Red Tower",
                    "primary_isbn13": "9781649374172",
                    "primary_isbn10": "1649374178"
                }
            ],
            "reviews": [
                {
                    "book_review_link": "",
                    "first_chapter_link": "",
                    "sunday_review_link": "",
                    "article_chapter_link": ""
                }
            ]
        },
        {
            "list_name": "Hardcover Fiction",
            "display_name": "Hardcover Fiction",
            "bestsellers_date": "2025-05-03",
            "published_date": "2025-05-18",
            "rank": 12,
            "rank_last_week": 8,
            "weeks_on_list": 27,
            "asterisk": 0,
            "dagger": 0,
            "amazon_product_url": "https://www.amazon.com/dp/1250899575?tag=thenewyorktim-20",
            "isbns": [
                {
                    "isbn10": "1250899575",
                    "isbn13": "9781250899576"
                },
                {
                    "isbn10": "1250899567",
                    "isbn13": "9781250899569"
                },
                {
                    "isbn10": "1420514725",
                    "isbn13": "9781420514728"
                },
                {
                    "isbn10": "1250899559",
                    "isbn13": "9781250899552"
                }
            ],
            "book_details": [
                {
                    "title": "THE WEDDING PEOPLE",
                    "description": "A woman who is down on her luck forms an unexpected bond with the bride at a wedding in Rhode Island.",
                    "contributor": "by Alison Espach",
                    "author": "Alison Espach",
                    "contributor_note": "",
                    "price": "0.00",
                    "age_group": "",
                    "publisher": "Holt",
                    "primary_isbn13": "9781250899576",
                    "primary_isbn10": "1250899575"
                }
            ],
            "reviews": [
                {
                    "book_review_link": "",
                    "first_chapter_link": "",
                    "sunday_review_link": "",
                    "article_chapter_link": ""
                }
            ]
        },
        {
            "list_name": "Hardcover Fiction",
            "display_name": "Hardcover Fiction",
            "bestsellers_date": "2025-05-03",
            "published_date": "2025-05-18",
            "rank": 13,
            "rank_last_week": 9,
            "weeks_on_list": 65,
            "asterisk": 0,
            "dagger": 0,
            "amazon_product_url": "https://www.amazon.com/dp/1250178630?tag=thenewyorktim-20",
            "isbns": [
                {
                    "isbn10": "1250178630",
                    "isbn13": "9781250178633"
                },
                {
                    "isbn10": "1250178657",
                    "isbn13": "9781250178657"
                }
            ],
            "book_details": [
                {
                    "title": "THE WOMEN",
                    "description": "A nurse follows her brother to serve during the Vietnam War and returns to a divided America.",
                    "contributor": "by Kristin Hannah",
                    "author": "Kristin Hannah",
                    "contributor_note": "",
                    "price": "0.00",
                    "age_group": "",
                    "publisher": "St. Martin's",
                    "primary_isbn13": "9781250178633",
                    "primary_isbn10": "1250178630"
                }
            ],
            "reviews": [
                {
                    "book_review_link": "",
                    "first_chapter_link": "",
                    "sunday_review_link": "",
                    "article_chapter_link": ""
                }
            ]
        },
        {
            "list_name": "Hardcover Fiction",
            "display_name": "Hardcover Fiction",
            "bestsellers_date": "2025-05-03",
            "published_date": "2025-05-18",
            "rank": 14,
            "rank_last_week": 10,
            "weeks_on_list": 44,
            "asterisk": 0,
            "dagger": 0,
            "amazon_product_url": "https://www.amazon.com/dp/0385550367?tag=thenewyorktim-20",
            "isbns": [
                {
                    "isbn10": "0385550367",
                    "isbn13": "9780385550369"
                },
                {
                    "isbn10": "0385550375",
                    "isbn13": "9780385550376"
                },
                {
                    "isbn10": "0593821254",
                    "isbn13": "9780593821251"
                }
            ],
            "book_details": [
                {
                    "title": "JAMES",
                    "description": "A reimagining of \u201cAdventures of Huckleberry Finn\u201d shines a different light on Mark Twain's classic, revealing new facets of the character of Jim.",
                    "contributor": "by Percival Everett",
                    "author": "Percival Everett",
                    "contributor_note": "",
                    "price": "0.00",
                    "age_group": "",
                    "publisher": "Doubleday",
                    "primary_isbn13": "9780385550369",
                    "primary_isbn10": "0385550367"
                }
            ],
            "reviews": [
                {
                    "book_review_link": "",
                    "first_chapter_link": "",
                    "sunday_review_link": "",
                    "article_chapter_link": ""
                }
            ]
        },
        {
            "list_name": "Hardcover Fiction",
            "display_name": "Hardcover Fiction",
            "bestsellers_date": "2025-05-03",
            "published_date": "2025-05-18",
            "rank": 15,
            "rank_last_week": 11,
            "weeks_on_list": 42,
            "asterisk": 0,
            "dagger": 0,
            "amazon_product_url": "https://www.amazon.com/dp/0593418913?tag=thenewyorktim-20",
            "isbns": [
                {
                    "isbn10": "0593418913",
                    "isbn13": "9780593418918"
                },
                {
                    "isbn10": "059341893X",
                    "isbn13": "9780593418932"
                },
                {
                    "isbn10": "0593867793",
                    "isbn13": "9780593867792"
                }
            ],
            "book_details": [
                {
                    "title": "THE GOD OF THE WOODS",
                    "description": "When a 13-year-old girl disappears from an Adirondack summer camp in 1975, secrets kept by the Van Laar family emerge.",
                    "contributor": "by Liz Moore",
                    "author": "Liz Moore",
                    "contributor_note": "",
                    "price": "0.00",
                    "age_group": "",
                    "publisher": "Riverhead",
                    "primary_isbn13": "9780593418918",
                    "primary_isbn10": "0593418913"
                }
            ],
            "reviews": [
                {
                    "book_review_link": "",
                    "first_chapter_link": "",
                    "sunday_review_link": "",
                    "article_chapter_link": ""
                }
            ]
        }
    ]
}
# Convert the dictionary to a JSON string
#son_data = json.dumps(data, indent=4)

#print(json_data)
print(data['results'])
# Out:
# [{'list_name': 'Hardcover Fiction', 'display_name': 'Hardcover Fiction', 'bestsellers_date': '2025-05-03', 'published_date': '2025-05-18', 'rank': 1, 'rank_last_week': 1, 'weeks_on_list': 2, 'asterisk': 0, 'dagger': 0, 'amazon_product_url': 'https://www.amazon.com/dp/059344129X?tag=thenewyorktim-20', 'isbns': [{'isbn10': '059344129X', 'isbn13': '9780593441299'}, {'isbn10': '0593441249', 'isbn13': '9780593441244'}], 'book_details': [{'title': 'GREAT BIG BEAUTIFUL LIFE', 'description': 'A writer looking for her big break competes against a Pulitzer winner to tell the story of an octogenarian with a storied past.', 'contributor': 'by Emily Henry', 'author': 'Emily Henry', 'contributor_note': '', 'price': '0.00', 'age_group': '', 'publisher': 'Berkley', 'primary_isbn13': '9780593441299', 'primary_isbn10': '059344129X'}], 'reviews': [{'book_review_link': '', 'first_chapter_link': '', 'sunday_review_link': '', 'article_chapter_link': ''}]}, {'list_name': 'Hardcover Fiction', 'display_name'
# ...

# %%
import threading
# Function to process each item
def process_item(item):
    if item['list_name'] == 'Hardcover Fiction':
        for book in item['book_details']:
            print(book['title'])

# Create and start threads
threads = []
for i in data['results']:
    thread = threading.Thread(target=process_item, args=(i,))
    threads.append(thread)
    thread.start()

# Wait for all threads to complete
for thread in threads:
    thread.join()
# Out:
# GREAT BIG BEAUTIFUL LIFE
# 25 ALIVE
# ENIGMA
# A MIND OF HER OWN
# THE PERFECT DIVORCE
# ONYX STORM
# STRANGERS IN TIME
# THE AMALFI CURSE
# SAY YOU'LL REMEMBER ME
# BROKEN COUNTRY
# IRON FLAME
# THE WEDDING PEOPLE
# THE WOMEN
# JAMES
# THE GOD OF THE WOODS

# %%
d=[]
for i in data['results']:
    isbn10=''
    isbn13=''
    title=''
    if i['list_name']=='Hardcover Fiction':
        #print(i['book_details'])
        for j in i['book_details']:
            #print(j['title'])
            d.append(j['title'])
        for k in i['isbns']:
            isbn10 = k['isbn10']
            isbn13 = k['isbn13']
            d.append(isbn10)
            d.append(isbn13)
        
print(d)
# Out:
# ['GREAT BIG BEAUTIFUL LIFE', '059344129X', '9780593441299', '0593441249', '9780593441244', '25 ALIVE', '0316569771', '9780316569774', '031656978X', '9780316569781', 'ENIGMA', '1250334233', '9781250334237', 'A MIND OF HER OWN', '0593498704', '9780593498705', '0593498712', '9780593498712', 'THE PERFECT DIVORCE', 'ONYX STORM', '1649374186', '9781649374189', '1649377150', '9781649377159', '1705085113', '9781705085110', '1420521861', '9781420521863', '1705085091', '9781705085097', 'STRANGERS IN TIME', '1538742055', '9781538742051', '153874208X', '9781538742082', 'THE AMALFI CURSE', '0778308006', '9780778308003', "SAY YOU'LL REMEMBER ME", '1538759195', '9781538759196', '0349442835', '9780349442839', '1668644991', '9781668644997', 'BROKEN COUNTRY', '166807818X', '9781668078181', '1668078201', '9781668078204', '1668144565', '9781668144565', '1420520725', '9781420520729', 'IRON FLAME', '1649374178', '9781649374172', '1705085083', '9781705085080', '034943705X', '9780349437057', 'THE WEDDING PE
# ...

# %%
import transformation
# Out:
# The kernel failed to start as 'NullHandler' could not be imported from 'most likely due to a circular import'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.
